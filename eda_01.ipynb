# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data/dataset.csv")
df.head()
# Out:
#                                                 text  \
# 0  The sheer, unadulterated arrogance required to...
# 1  It is entirely baffling how an executive manag...
# 2  Your team has aggressively managed to complete...
# 3  Synergy is just a fancy word for doing all the...
# 4  Contemporary linguistic theories frequently ex...
#
#                                           clean_text     style        tone
# 0  the sheer , unadulterated arrogance require to...  academic  aggressive
# 1  it be entirely baffle how an executive manager...  business  aggressive
# 2  your team have aggressively manage to complete...  business  aggressive
# 3  synergy be just a fancy word for do all the wo...  business   sarcastic
# 4  contemporary linguistic theory frequently expl...  academic     neutral

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        1000 non-null   str
#  1   clean_text  1000 non-null   str
#  2   style       1000 non-null   str
#  3   tone        1000 non-null   str
# dtypes: str(4)
# memory usage: 819.5 KB

# %%
df.isnull().sum()
# Out:
# text          0
# clean_text    0
# style         0
# tone          0
# dtype: int64

# %%
style_counts = df["style"].value_counts()

print(style_counts)

sns.barplot(x=style_counts.index, y=style_counts.values, hue=style_counts.index, legend=False)

plt.title("Style Distribution")
plt.xlabel("Style")
plt.ylabel("Count")

plt.show()
# Out:
# style
# academic    200
# business    200
# informal    200
# formal      200
# literaly    200
# Name: count, dtype: int64

# %%
tone_counts = df["tone"].value_counts()

print(tone_counts)

sns.barplot(x=tone_counts.index, y=tone_counts.values, hue=tone_counts.index, legend=False)

plt.title("Tone Distribution")
plt.xlabel("Tone")
plt.ylabel("Count")

plt.show()
# Out:
# tone
# aggressive    200
# sarcastic     200
# neutral       200
# urgent        200
# friendly      200
# Name: count, dtype: int64

# %%
combo_counts = (
    df.groupby(["style", "tone"])
    .size()
    .unstack(fill_value=0)
)

print(combo_counts)

combo_counts.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Style + Tone Distribution")
plt.ylabel("Count")

plt.show()
# Out:
# tone      aggressive  friendly  neutral  sarcastic  urgent
# style
# academic          40        40       40         40      40
# business          40        40       40         40      40
# formal            40        40       40         40      40
# informal          40        40       40         40      40
# literaly          40        40       40         40      40

# %%
df["clean_text"] = df["clean_text"].fillna("").astype(str)
df["word_count"] = df["clean_text"].apply(lambda x: len(x.split()))
df["text_length"] = df["clean_text"].apply(len)

df["text_length"].describe()
# Out:
# count    1000.000000
# mean      391.887000
# std       227.633348
# min         9.000000
# 25%       198.000000
# 50%       391.500000
# 75%       584.500000
# max       800.000000
# Name: text_length, dtype: float64

# %%
df["text_length"].hist(
    bins=30,
    figsize=(10, 5)
)

plt.title("Text Length Distribution")

plt.xlabel("Characters")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(
    data=df,
    x="text_length",
    hue="style",
    multiple="stack",
    bins=30
)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(40))

plt.title("Text Length Stacked Histogram by Style")
plt.xlabel("Characters")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(
    data=df,
    x="text_length",
    hue="tone",
    multiple="stack",
    bins=30
)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(40))
plt.title("Text Length Stacked Histogram by Tone")
plt.xlabel("Characters")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="style", y="word_count", hue="tone")
plt.title("Word Count Distribution by Style and Tone")
plt.show()
